# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
titanic_data = pd.read_csv('titanic.csv')

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import seaborn as sns

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
 
training = titanic_data.iloc[:, :-1]
testing = titanic_data.iloc[:, -1]
 
# split the dataset
training_train, training_test, testing_train, testing_test = train_test_split(
    training, testing, test_size=0.05,)

# %%
training
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
testing
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
training.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
testing.describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
training.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# dtype: int64

# %%
testing.isnull().sum()
# Out:
# 2

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
titanic_data[titanic_data['Sex']=='male'].count()['Age']
# Out:
# 453

# %%
np.where((titanic_data['Age']=='male') & (titanic_data['Survived']=='1'))
# Out:
# (array([], dtype=int64),)

# %%
titanic_data.groupby('Age')['Survived'].sum()
# Out:
# Age
# 0.42     1
# 0.67     1
# 0.75     2
# 0.83     2
# 0.92     1
#         ..
# 70.00    0
# 70.50    0
# 71.00    0
# 74.00    0
# 80.00    1
# Name: Survived, Length: 88, dtype: int64

# %%
titanic_data.duplicated().sum()
# Out:
# 0

# %%
sns.boxplot(y=titanic_data['Age'],x=titanic_data['Survived'],hue=titanic_data['Sex'])
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.boxplot(y=titanic_data['Parch'],x=titanic_data['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='Parch'>

# %%
titanic_data.groupby('Sex')['Survived'].sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
Totalmen = titanic_data[titanic_data['Sex']=='male']['PassengerId'].count()
print(Totalmen)
print("Percentage of men who survived",round((109/577)*100))
# Out:
# 577
# Percentage of men who survived 19

# %%
TotalWomen = titanic_data[titanic_data['Sex']=='female']['PassengerId'].count()
print(TotalWomen)
print("Percentage of women who survived",round((233/314)*100))
# Out:
# 314
# Percentage of women who survived 74

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_data['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
titanic_data['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
titanic_copy = titanic_data.copy()
titanic_copy
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_copy['Embarked'].replace(np.nan,titanic_copy['Embarked'].mode().values[0],inplace=True)

# %%
sns.boxplot(titanic_copy['Age'])
# Out:
# <Axes: >

# %%
titanic_copy['Age'].median()
# Out:
# 28.0

# %%
titanic_copy['Age'].replace(np.nan,titanic_copy['Age'].median(),inplace=True)

# %%
titanic_copy
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_copy.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
training.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 training.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
training=training.drop(['Name'],axis=1)

# %%
training
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin
# 0           A/5 21171   7.2500   NaN
# 1            PC 17599  71.2833   C85
# 2    STON/O2. 3101282   7.9250   NaN
# 3              113803  53.1000  C123
# ...

# %% [raw]
# training.corr()

# %%
training.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 training.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
training['Sex'] = training['Sex'].map({'male': 1, 'female': 0})

# %%
training
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0              1         0       3    1  22.0      1      0         A/5 21171
# 1              2         1       1    0  38.0      1      0          PC 17599
# 2              3         1       3    0  26.0      0      0  STON/O2. 3101282
# 3              4         1       1    0  35.0      1      0            113803
# 4              5         0       3    1  35.0      0      0            373450
# ..           ...       ...     ...  ...   ...    ...    ...               ...
# 886          887         0       2    1  27.0      0      0            211536
# 887          888         1       1    0  19.0      0      0            112053
# 888          889         0       3    0   NaN      1      2        W./C. 6607
# 889          890         1       1    1  26.0      0      0            111369
# 890          891         0       3    1  32.0      0      0            370376
#
#         Fare Cabin
# ...

# %%
training.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 training.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
training=training.drop(['Ticket','Cabin'],axis=1)

# %%
training
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0              1         0       3    1  22.0      1      0   7.2500
# 1              2         1       1    0  38.0      1      0  71.2833
# 2              3         1       3    0  26.0      0      0   7.9250
# 3              4         1       1    0  35.0      1      0  53.1000
# 4              5         0       3    1  35.0      0      0   8.0500
# ..           ...       ...     ...  ...   ...    ...    ...      ...
# 886          887         0       2    1  27.0      0      0  13.0000
# 887          888         1       1    0  19.0      0      0  30.0000
# 888          889         0       3    0   NaN      1      2  23.4500
# 889          890         1       1    1  26.0      0      0  30.0000
# 890          891         0       3    1  32.0      0      0   7.7500
#
# [891 rows x 8 columns]

# %%
training.corr()
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144  0.042939  0.036847 -0.057527
# Survived       -0.005007  1.000000 -0.338481 -0.543351 -0.077221 -0.035322
# Pclass         -0.035144 -0.338481  1.000000  0.131900 -0.369226  0.083081
# Sex             0.042939 -0.543351  0.131900  1.000000  0.093254 -0.114631
# Age             0.036847 -0.077221 -0.369226  0.093254  1.000000 -0.308247
# SibSp          -0.057527 -0.035322  0.083081 -0.114631 -0.308247  1.000000
# Parch          -0.001652  0.081629  0.018443 -0.245489 -0.189119  0.414838
# Fare            0.012658  0.257307 -0.549500 -0.182333  0.096067  0.159651
#
#                 Parch      Fare
# PassengerId -0.001652  0.012658
# Survived     0.081629  0.257307
# Pclass       0.018443 -0.549500
# Sex         -0.245489 -0.182333
# Age         -0.189119  0.096067
# SibSp        0.414838  0.159651
# Parch        1.000000  0.216225
# ...

# %%
sns.heatmap(training.corr(),annot=True)
# Out:
# <Axes: >

# %%
titanic_copy
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_copy1 =titanic_copy.copy()

# %%
titanic_copy1=titanic_copy1.drop(['Survived'],axis=1)

# %%
testing1=titanic_copy1

# %%
testing1
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
testing1['Sex'] = testing1['Sex'].map({'male': 1, 'female': 0})

# %%
y_train=training['Survived']

features =['Pclass','Sex','SibSp','Parch']
X_train=pd.get_dummies(training[features])
X_test= pd.get_dummies(testing1[features])

# %%
training
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0              1         0       3    1  22.0      1      0   7.2500
# 1              2         1       1    0  38.0      1      0  71.2833
# 2              3         1       3    0  26.0      0      0   7.9250
# 3              4         1       1    0  35.0      1      0  53.1000
# 4              5         0       3    1  35.0      0      0   8.0500
# ..           ...       ...     ...  ...   ...    ...    ...      ...
# 886          887         0       2    1  27.0      0      0  13.0000
# 887          888         1       1    0  19.0      0      0  30.0000
# 888          889         0       3    0   NaN      1      2  23.4500
# 889          890         1       1    1  26.0      0      0  30.0000
# 890          891         0       3    1  32.0      0      0   7.7500
#
# [891 rows x 8 columns]

# %%
titanic_copy['Sex'] = titanic_copy['Sex'].map({'male': 1, 'female': 0})

# %%
testing1
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
titanic_copy
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
y_train=training['Survived']

features =['Pclass','Sex','SibSp','Parch']
X_train=pd.get_dummies(training[features])
X_test= pd.get_dummies(testing1[features])

# %%
training_copy=titanic_copy

# %%
training
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0              1         0       3    1  22.0      1      0   7.2500
# 1              2         1       1    0  38.0      1      0  71.2833
# 2              3         1       3    0  26.0      0      0   7.9250
# 3              4         1       1    0  35.0      1      0  53.1000
# 4              5         0       3    1  35.0      0      0   8.0500
# ..           ...       ...     ...  ...   ...    ...    ...      ...
# 886          887         0       2    1  27.0      0      0  13.0000
# 887          888         1       1    0  19.0      0      0  30.0000
# 888          889         0       3    0   NaN      1      2  23.4500
# 889          890         1       1    1  26.0      0      0  30.0000
# 890          891         0       3    1  32.0      0      0   7.7500
#
# [891 rows x 8 columns]

# %%
training_copy
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
testing1
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
testing_copy=testing1.copy()

# %%
X_train_scaled = pd.get_dummies(training_copy[features])
X_test_scaled = pd.get_dummies(testing_copy[features])

# %%
from scipy.stats import zscore
X_train_scaled = X_train_scaled.apply(zscore)
X_test_scaled = X_test_scaled.apply(zscore)

# %%
model = RandomForestClassifier(n_estimators=100,max_depth=5,random_state=123)
model.fit(X_train,y_train)

predictions = model.predict(X_test)

output = pd.DataFrame({'PassengerId': testing1.PassengerId, 'Survived': predictions})
output.to_csv('RF_submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!

# %%
X_train.head()
# Out:
#    Pclass  Sex  SibSp  Parch
# 0       3    1      1      0
# 1       1    0      1      0
# 2       3    0      0      0
# 3       1    0      1      0
# 4       3    1      0      0

# %%
rf_score = model.score(X_train,y_train)
rf_score
# Out:
# 0.8148148148148148

# %%
sns.set_theme(style="whitegrid")
sns.histplot( training, x="Age", hue="Survived", multiple="dodge")
plt.xticks(rotation=90)
plt.xlabel("Age")
plt.ylabel("Pasanger Count")
plt.title("Survival based on Age")
plt.show()

# %%
sns.violinplot(data=training, x='Survived', y= "Age" , inner='quartile')
plt.title("Survival Based on Age")
plt.xlabel("Survied (No = 0 or Yes = 1)")
plt.ylabel("Age(yrs)")

plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.histplot( training, x="Age", hue="Sex", multiple="dodge")
plt.xticks(rotation=90)
plt.xlabel("Age")
plt.ylabel("Pasanger Count")
plt.title("Sex Distribution by Age")
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.histplot( training, x="Sex", hue="Survived", multiple="dodge")
plt.xticks(rotation=90)
plt.xlabel("Age")
plt.ylabel("Pasanger Count")
plt.title("Sex Distribution by Age")
plt.show()

# %%
sns.violinplot(data=training, x='Sex', y= "Survived" , inner='quartile')
plt.title("Survival Based on Sex Distribution")
plt.xlabel("Survaved")
plt.ylabel("Survived (Yes = 1 or No = 0)")

plt.show()

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={'height_ratios': (.15, .85)}, figsize=(10, 6))
sns.set_style("darkgrid")
sns.boxplot(data=training, x="Fare", ax=ax_box)
sns.histplot(data=training, x="Fare", kde=True, ax=ax_hist)
ax_box.set(xlabel="Fare")
plt.xlabel("Fare Price ($)")

plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.histplot( training, x="Fare", hue="Survived", multiple="dodge")
plt.xticks(rotation=90)
plt.xlabel("Fare ($)")
plt.ylabel("Pasanger Count")
plt.title("Survival based on Fare")
plt.show()

# %%
sns.violinplot(data=training, x='Survived', y= "Fare" , inner='quartile')
plt.title("Survival Based on Fare")
plt.xlabel("Survied (No = 0 or Yes = 1)")
plt.ylabel("Fare ($)")

plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.histplot( training, x="Pclass", hue="Survived", multiple="dodge", bins=6)
plt.xticks(rotation=90)
plt.xlabel("Pclass")
plt.ylabel("Pasanger Count")
plt.title("Pclass")
plt.show()

# %%
sns.violinplot(data=training, y='Survived', x= "SibSp" , inner='quartile')
plt.title("Survival Based Numbers Family members")
plt.xlabel("Family members")
plt.ylabel("Survied (No = 0 or Yes = 1)")

plt.show()

# %%
sns.violinplot(data=training, y='Survived', x= "Parch" , inner='quartile')
plt.title("Survival Based on Parch")
plt.xlabel("Parch")
plt.ylabel("Survied (No = 0 or Yes = 1)")

plt.show()

# %%
random_forest =  RandomForestClassifier(random_state = 1, criterion = 'entropy', class_weight = 'balanced') 
random_forest.fit(X_train,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', criterion='entropy',
#                        random_state=1)

# %%
def metrics_score(actual, predicted):
    print(classification_report(actual, predicted))
    cm = confusion_matrix(actual, predicted)
    plt.figure(figsize=(8,5))
    sns.heatmap(cm, annot=True,  fmt='.2f', xticklabels=['Not Attrite', 'Attrite'], 
                yticklabels=['Not Attrite', 'Attrite'])
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# %%
random_forest =  RandomForestClassifier(random_state = 1, criterion = 'entropy', class_weight = 'balanced') 
random_forest.fit(X_train,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', criterion='entropy',
#                        random_state=1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lrm = LogisticRegression(solver="newton-cg",max_iter=10000,penalty='none',verbose=True,n_jobs=2)
lrm.fit(X_train,y_train)
# Out:
# C:\Users\manaa\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1182: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 out of   1 | elapsed:    0.6s finished
# LogisticRegression(max_iter=10000, n_jobs=2, penalty='none', solver='newton-cg',
#                    verbose=True)

# %%
lrm_ytrain_predict = lrm.predict(X_train)
lrm_ytest_predict = lrm.predict(X_test)

# %%
lrm_ytest_predict_prob = lrm.predict_proba(X_test)
pd.DataFrame(lrm_ytest_predict_prob).head()
# Out:
#           0         1
# 0  0.913272  0.086728
# 1  0.092253  0.907747
# 2  0.344766  0.655234
# 3  0.092253  0.907747
# 4  0.892855  0.107145

# %%
log_score=lrm.score(X_train,y_train)
log_score
# Out:
# 0.8002244668911336

# %%
logistic_predictions=lrm.predict(X_test)
logistic_output = pd.DataFrame({'PassengerId': testing1.PassengerId, 'Survived': logistic_predictions})
logistic_output.to_csv('logistic_submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(X_train,y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
lda_ytrain_pred = lda.predict(X_train)

# %%
lda_score = lda.score(X_train,y_train)
lda_score
# Out:
# 0.7912457912457912

# %%
lda_predictions=lda.predict(X_test)
lda_output = pd.DataFrame({'PassengerID':testing1['PassengerId'],'Survived':lda_predictions})
lda_output.to_csv('lda_submission.csv', index=False)
print("Your submission for LDA was successfully saved!")
# Out:
# Your submission for LDA was successfully saved!

# %%
training_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %%
testing_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Pclass       891 non-null    int64
#  2   Name         891 non-null    object
#  3   Sex          891 non-null    int64
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(X_train,y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
lda_ytrain_pred = lda.predict(X_train)

# %%
lda_predictions=lda.predict(X_test)
lda_output = pd.DataFrame({'Sex':testing1['Sex'],'Survived':lda_predictions})
lda_output.to_csv('Sex_submission.csv', index=False)
print("Your submission for LDA was successfully saved!")
# Out:
# Your submission for LDA was successfully saved!
